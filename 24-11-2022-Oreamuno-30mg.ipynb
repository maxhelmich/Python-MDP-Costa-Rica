# %%
# import necessary packages
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt
import warnings
import random
from matplotlib.ticker import PercentFormatter  
from datetime import datetime
from pandas import read_csv
import datetime as dt
import matplotlib.dates as mdates
warnings.simplefilter('ignore') # filter some warning messages
# %matplotlib inline

# %%
import numpy as np
import pandas as pd

def dt64_to_float(dt64):
    """Converts numpy.datetime64 to year as float.

    Rounded to days

    Parameters
    ----------
    dt64 : np.datetime64 or np.ndarray(dtype='datetime64[X]')
        date data

    Returns
    -------
    float or np.ndarray(dtype=float)
        Year in floating point representation
    """

    year = dt64.astype('M8[Y]')
    # print('year:', year)
    days = (dt64 - year).astype('timedelta64[D]')
    # print('days:', days)
    year_next = year + np.timedelta64(1, 'Y')
    # print('year_next:', year_next)
    days_of_year = (year_next.astype('M8[D]') - year.astype('M8[D]')
                    ).astype('timedelta64[D]')
    # print('days_of_year:', days_of_year)
    dt_float = 1970 + year.astype(float) + days / (days_of_year)
    # print('dt_float:', dt_float)
    return dt_float

if __name__ == "__main__":

    dates = np.array([
        '1970-01-01', '2014-01-01', '2020-12-31', '2019-12-31', '2010-04-28'],
        dtype='datetime64[D]')

    df = pd.DataFrame({
        'date': dates,
        'number': np.arange(5)
        })

    df['date_float'] = dt64_to_float(df['date'].to_numpy())


    dt64 = np.datetime64( "2011-11-11" )
    
#Inladen + sorteren van de dataset op regio
#Geeft het aantal unieke systemen in de verschillende regio's

data = pd.read_excel (r'FulldataEXCEL.xlsx',sheet_name = 'Above30mg')
df = pd.DataFrame(data,columns= ['FECHA DE MUESTREO','SISTEMA DE ABASTECIMIENTO','RESULTADO','PUNTO DE MUESTREO','CANTÓN'])
# display(df)
SortData = df.sort_values(by=['FECHA DE MUESTREO'], ascending=True)
# display(SortData)
#Dit hoeft niet eens, omdat er geen nul waarde in de data set zitten 
Cartago=SortData.dropna(subset=['RESULTADO'])
# display(SortData2)
Cartago.replace('ALVARADO', 'Alvarado', inplace=True)
Cartago.replace('CARTAGO', 'Cartago', inplace=True)
Cartago.replace('OREAMUNO', 'Oreamuno', inplace=True)
Cartago.replace('PARAÍSO', 'Paraíso', inplace=True)

counts = Cartago['CANTÓN'].value_counts()
display(counts)
Cartago_city = Cartago[Cartago["CANTÓN"] == 'Cartago']
Oreamuno = Cartago[Cartago["CANTÓN"] == 'Oreamuno']
Paraíso = Cartago[Cartago["CANTÓN"] == 'Paraíso']
Alvarado = Cartago[Cartago["CANTÓN"] == 'Alvarado']
El_Guarco = Cartago[Cartago["CANTÓN"] == 'El Guarco']

#In de meeste cellen staan dus meerdere waardes, die worden hier gesplits 
#en van elke value wordt een nieuwe rij gemaakt 

def splitDataFrameList(df,target_column,separator,output_type=float):
    ''' df = dataframe to split,
    target_column = the column containing the values to split
    separator = the symbol used to perform the split
    returns: a dataframe with each entry for the target column separated, with each element moved into a new row. 
    The values in the other columns are duplicated across the newly divided rows.
    '''
    def splitListToRows(row,row_accumulator,target_column,separator):
        split_row = row[target_column].split(separator)
        for s in split_row:
            new_row = row.to_dict()
            new_row[target_column] = s
            row_accumulator.append(new_row)
    new_rows = []
    df.apply(splitListToRows,axis=1,args = (new_rows,target_column,separator))
    new_df = pd.DataFrame(new_rows)
    return new_df
# Out:
# Oreamuno     171
# Cartago      138
# Paraíso       35
# El Guarco     21
# Alvarado      20
# GUARCO        10
# CARTAGO        4
# OREAMUNO       1
# Name: CANTÓN, dtype: int64

# %%
#In deze cel worden de volgende handelingen uitgevoerd: Creeëren van een nieuwe
#excel, het sorteren van de dataset op 'Resultaten van hoog --> laag', 
#de datums, resultaten en syteem namen worden geextract


Oreamuno.to_excel('Oreamuno.xlsx')
Oreamuno2 = pd.read_excel (r'Oreamuno.xlsx',index_col=1,parse_dates=True )
Oreamuno3 = pd.DataFrame(Oreamuno2,columns= ['SISTEMA DE ABASTECIMIENTO','RESULTADO','CANTÓN','PUNTO DE MUESTREO'])
# Cartago_city3.sort_values(by=['RESULTADO'],ascending=False, inplace=True)
#Tijd
dates_input = Oreamuno3.index.values.astype('datetime64[D]')
Time = dt64_to_float(dates_input)
Time_rounded = np.round(Time,3)
# #Resultaten
Resultado = Oreamuno3['RESULTADO']
# #Systeem namen, deze zijn echter niet allen uniek --> 

Locaties = Oreamuno3['PUNTO DE MUESTREO']

# #Daarom wordt deze functies gecreert die alleen systemen met een unieke naam 
# #eruit filteren en samenvoegen in een array

Systema = Oreamuno3['SISTEMA DE ABASTECIMIENTO']
print(len(Systema))
def VulFunc(Naam_Array,Naam_Array_leeg):
    k =1
    for j in range(len(Naam_Array_leeg)+1):
        if j+1 == (len(Naam_Array_leeg)+1)and k==1:
            Naam_Array_leeg.append(Naam_Array)

        else:
#             print('door')
            for i in range(len(Naam_Array_leeg)):
                if Naam_Array != Naam_Array_leeg[i]:
                    continue
                else:
                    k = 2 
    return Naam_Array_leeg

# display(Cartago_city3.head(112))
# Out:
# 171

# %%
#Hier wordt de lege array opgevuld met de unieke systeem namen
display(Oreamuno3)
systema_unique = []
for i in range(len(Oreamuno3['SISTEMA DE ABASTECIMIENTO'])):
    VulFunc(Oreamuno3['SISTEMA DE ABASTECIMIENTO'][i],systema_unique)
print(systema_unique)
print(len(systema_unique))
# Out:
#                                   SISTEMA DE ABASTECIMIENTO  RESULTADO  \
# FECHA DE MUESTREO
# 2009-07-04                     COT DE OREAMUNO: SECTOR ESTE      30.59
# 2009-09-23         SANTA EDUVIGES DE SAN RAFAEL DE OREAMUNO      55.92
# 2009-09-23                 YERRIS DE SAN RAFAEL DE OREAMUNO      41.38
# 2009-09-23                   SAN RAFAEL DE OREAMUNO: CENTRO      65.24
# 2009-09-23           SAN RAFAEL DE OREAMUNO: SECTOR NORESTE      39.20
# ...                                                     ...        ...
# 2021-07-06                     COT DE OREAMUNO: SECTOR ESTE      30.85
# 2021-07-06                     COT DE OREAMUNO: SECTOR ESTE      30.38
# 2021-09-23                           SANTA ROSA DE OREAMUNO      36.16
# 2021-09-23                           SANTA ROSA DE OREAMUNO      33.71
# 2021-09-23                           SANTA ROSA DE OREAMUNO      36.13
#
#                      CANTÓN                       PUNTO DE MUESTREO
# FECHA DE MUESTREO
# 2009-07-04         Oreamuno                   NACIENTE SAN MARTÍN 3
# 2009-09-23         Oreamuno                       NACIENTE CARRILLO
# 2009-09-23         Oreamuno                        NACIENTE TURBINA
# 2009-09-23         Oreamuno  MEZCLA NACIENTES CARLOS GÓMEZ 1, 2 Y 3
# 2009-09-23         Oreamuno                        MEZCLA NACIENTES
# ...                     ...                                     ...
# 2021-07-06         Oreamuno         M. NACIENTES SAN MARTÍN 1,2 Y 3
# 2021-07-06         Oreamuno                                   RED 2
# 2021-09-23         Oreamuno                                   RED 1
# 2021-09-23         Oreamuno                NACIENTE MANUEL GRANADOS
# 2021-09-23         Oreamuno                      NACIENTE AGUA FRÍA
#
# [171 rows x 4 columns]
# ['COT DE OREAMUNO: SECTOR ESTE', 'SANTA EDUVIGES DE SAN RAFAEL DE OREAMUNO', 'YERRIS DE SAN RAFAEL DE OREAMUNO', 'SAN RAFAEL DE OREAMUNO: CENTRO', 'SAN RAFAEL DE OREAMUNO: SECTOR NORESTE', 'SAN RAFAEL DE OREAMUNO: SECTOR NORTE', 'POTRERO CERRADO DE OREAMUNO', 'SAN ISIDRO DE SANTA ROSA DE OREAMUNO', 'STA ROSA DE OREAMUNO CARTAGO: AGUA FRIA', 'CALLE CHINCHILLA VIEJA DE SAN RAFAEL DE OREAMUNO', 'CIPRESES, ORATORIO Y CAPIRA DE OREAMUNO', 'SANTA ROSA DE OREAMUNO: SECTOR NACIENTE DE AGUA FRÍA', 'SANTA ROSA DE OREAMUNO', 'PASO ANCHO Y BOQUERÓN DE OREAMUNO', 'COT DE OREAMUNO: SECTOR OESTE', 'SANTA ROSA DE OREAMUNO: SECTOR NACIENTE DE AGUA FRIA', 'PASO ANCHO Y BOQUERÓN DE OREAMUNO: SECT. NAC EL SALTO', 'LA CHINCHILLA SAN RAFAEL DE OREAMUNO: CENTRO', 'MATA DE MORA SAN RAFAEL DE OREAMUNO', 'EL SALTO DE OREAMUNO', 'HIGUERONES DE OREAMUNO', 'CALLE CHINCHILLA VIEJA Y YERRIS DE SAN RAFAEL DE OREAMUNO', 'SAN RAFAEL DE OREAMUNO MATA DE MORA (SECTOR NORESTE)', 'SAN RAFAEL DE OREAMUNO LA CHINCHILLA: CENTRO', 'SAN RAFAEL DE OREAMUNO LA CHINCHILLA:CENTRO', 'CALLE LUCAS DE OREAMUNO', 'CIPRESES DE OREAMUNO: SECTOR NACIENTE CARLOS CALVO', 'SAN PABLO DE SANTA ROSA: SECTOR FINCA SAN BOSCO', 'CIPRESES DE OREAMUNO']
# 29

# %%
#in deze functie worden de drie elementen gecombineerd: Tijd, Resultaen en 
#systemen. Aleen de systemen waarbij de waarde boven de 50 uitkomt zal worden
#geplot. De output is een grafiek met twee threshold values + dataplotten over
#tijd en de hoeveelheid data punten aangegeven door de individuele 
#markeerpunten. Daarnaast worden de probleem gevallen nitraat hoeveelheden > 50, 
#opgeslagen in de array: 'Problems'
def Sub_systemen(nummer):
    SAN_RAFAEL_DE_OREAMUNO_CENTRO = np.zeros(251)
    SAN_RAFAEL_DE_OREAMUNO_CENTRO_TIME = np.zeros(251)
#     SAN_RAFAEL_DE_OREAMUNO_CENTRO_lOCATION = np.zeros(251)
    for i in range(171):
        if Systema[i]== systema_unique[nummer]:
                SAN_RAFAEL_DE_OREAMUNO_CENTRO[i] = Resultado[i]
                SAN_RAFAEL_DE_OREAMUNO_CENTRO_TIME[i] = Time_rounded[i]
#                 SAN_RAFAEL_DE_OREAMUNO_lOCATION[i] = Locaties[i]
    #             print('ja') 

    a = SAN_RAFAEL_DE_OREAMUNO_CENTRO
    a0 = a[a != 0]
    b = SAN_RAFAEL_DE_OREAMUNO_CENTRO_TIME
    b0 = b[b != 0]
#     c = SAN_RAFAEL_DE_OREAMUNO_CENTRO_LOCATION
#     c0 = c[c != 0]
    
    
    m = 1 
    for i in range(len(a0)):
        if a0[i] > 30:
            plt.title(f'{systema_unique[nummer]}', color = 'red')
#             Problems.append(f'{systema_unique[nummer]}')
            plt.ylabel('Nitrate in mg/l')
#             axs[i,j].plot(b0,a0,marker='o', markerfacecolor='blue', markersize=12)
            plt.plot(b0,a0,marker='o', markerfacecolor='blue', markersize=12)
            plt.axhline(40, color = 'yellow')
            plt.axhline(50, color = 'red')
            plt.xticks(rotation=90)
            plt.xlim([2009, 2022])
            plt.title(f'{systema_unique[nummer]}',fontsize = 13)
            m = 2 
            break
    return  plt.plot(b0,a0,marker='o', markerfacecolor='blue', markersize=12);
#, a0, b0, Problems

# %%
#Deze functie wordt gebruikt om onderscheidt te maken tussen de subplots die 
#wel >50 en niet <50 geplot moeten worden, door een m = 1 of m = 2 toe te wijzen. 
def Sub_systemen_m(nummer):
    SAN_RAFAEL_DE_OREAMUNO_CENTRO = np.zeros(251)
    SAN_RAFAEL_DE_OREAMUNO_CENTRO_TIME = np.zeros(251)
#     SAN_RAFAEL_DE_OREAMUNO_CENTRO_LOCATION = np.zeros(251)
    for i in range(171):
        if Systema[i]== systema_unique[nummer]:
                SAN_RAFAEL_DE_OREAMUNO_CENTRO[i] = Resultado[i]
                SAN_RAFAEL_DE_OREAMUNO_CENTRO_TIME[i] = Time_rounded[i]
#                 SAN_RAFAEL_DE_OREAMUNO_CENTRO_LOCATION[i] = Locaties[i]
    #             print('ja') 

    a = SAN_RAFAEL_DE_OREAMUNO_CENTRO
    a0 = a[a != 0]
    b = SAN_RAFAEL_DE_OREAMUNO_CENTRO_TIME
    b0 = b[b != 0]
#     c = SAN_RAFAEL_DE_OREAMUNO_CENTRO_LOCATION
#     c0 = c[c != 0]
    
    m = 1 
    for i in range(len(a0)):
        if a0[i] > 30:
            m = 2 
            break
    return  m

# %%
fig = plt.figure(figsize=(20,20));
for i in range(9):
    if Sub_systemen_m(i) == 2:
        plt.subplot(3,3,i+1);
#         #Sub_systemen(i);
        print(Sub_systemen(i))
# print(Problems)  
fig.suptitle('Systems >30 mg/l in Oreamuno',fontsize = 20 ) 
fig.savefig('First_9_Oreamuno_timeline_from30mg')
# Out:
# [<matplotlib.lines.Line2D object at 0x00000279E6E5F8E0>]
# [<matplotlib.lines.Line2D object at 0x00000279E7529EE0>]
# [<matplotlib.lines.Line2D object at 0x00000279E7561F10>]
# [<matplotlib.lines.Line2D object at 0x00000279E757C490>]
# [<matplotlib.lines.Line2D object at 0x00000279E8557A30>]
# [<matplotlib.lines.Line2D object at 0x00000279E859A8E0>]
# [<matplotlib.lines.Line2D object at 0x00000279E85E5CD0>]
# [<matplotlib.lines.Line2D object at 0x00000279E862C3D0>]
# [<matplotlib.lines.Line2D object at 0x00000279E867E790>]

# %%
fig = plt.figure(figsize=(20,20));
for i in range(9):
    if Sub_systemen_m(i+9) == 2:
        plt.subplot(3,3,i+1);
#         #Sub_systemen(i);
        print(Sub_systemen(i+9))
# print(Problems)  
fig.suptitle('Systems >30 mg/l in Oreamuno',fontsize = 20 ) 
fig.savefig('Second_9_Oreamuno_timeline_from30mg')
# Out:
# [<matplotlib.lines.Line2D object at 0x00000279E86B8520>]
# [<matplotlib.lines.Line2D object at 0x00000279E87110D0>]
# [<matplotlib.lines.Line2D object at 0x00000279E875F280>]
# [<matplotlib.lines.Line2D object at 0x00000279E87AE760>]
# [<matplotlib.lines.Line2D object at 0x00000279E880BDC0>]
# [<matplotlib.lines.Line2D object at 0x00000279E8865E20>]
# [<matplotlib.lines.Line2D object at 0x00000279E88BDFD0>]
# [<matplotlib.lines.Line2D object at 0x00000279E88FCD60>]
# [<matplotlib.lines.Line2D object at 0x00000279E895D730>]

# %%
fig = plt.figure(figsize=(20,20));
for i in range(9):
    if Sub_systemen_m(i+18) == 2:
        plt.subplot(3,3,i+1);
#         #Sub_systemen(i);
        print(Sub_systemen(i+18))
# print(Problems)  
fig.suptitle('Systems >30 mg/l in Oreamuno',fontsize = 20 ) 
fig.savefig('Third_9_Oreamuno_timeline_from30mg')
# Out:
# [<matplotlib.lines.Line2D object at 0x00000279E8AC69A0>]
# [<matplotlib.lines.Line2D object at 0x00000279E8B19F40>]
# [<matplotlib.lines.Line2D object at 0x00000279E8B635E0>]
# [<matplotlib.lines.Line2D object at 0x00000279E8BB0130>]
# [<matplotlib.lines.Line2D object at 0x00000279E8BFA790>]
# [<matplotlib.lines.Line2D object at 0x00000279E8A52C40>]
# [<matplotlib.lines.Line2D object at 0x00000279E89E99D0>]
# [<matplotlib.lines.Line2D object at 0x00000279E89F8D00>]
# [<matplotlib.lines.Line2D object at 0x00000279E86DF130>]

# %%
display(Resultado)
# Out:
# FECHA DE MUESTREO
# 2009-07-04    30.59
# 2009-09-23    55.92
# 2009-09-23    41.38
# 2009-09-23    65.24
# 2009-09-23    39.20
#               ...
# 2021-07-06    30.85
# 2021-07-06    30.38
# 2021-09-23    36.16
# 2021-09-23    33.71
# 2021-09-23    36.13
# Name: RESULTADO, Length: 171, dtype: float64

# %%
import pandas as pd
# interval = pd.Interval(pd.Timestamp('2020-01-01 00:00:00'), pd.Timestamp('2021-01-01 00:00:00'), closed='left')
# print(interval)
Resultado = Oreamuno3['RESULTADO']
# display(Cartago_city3)
Resultado.index

Year2008 = Resultado.loc['2008-01-01':'2009-01-01']
Year2009 = Resultado.loc['2009-01-01':'2010-01-01']
Year2010 = Resultado.loc['2010-01-01':'2011-01-01']
Year2011 = Resultado.loc['2011-01-01':'2012-01-01']
Year2012 = Resultado.loc['2012-01-01':'2013-01-01']
Year2013 = Resultado.loc['2013-01-01':'2014-01-01']
Year2014 = Resultado.loc['2014-01-01':'2015-01-01']
Year2015 = Resultado.loc['2015-01-01':'2016-01-01']
Year2016 = Resultado.loc['2016-01-01':'2017-01-01']
Year2017 = Resultado.loc['2017-01-01':'2018-01-01']
Year2018 = Resultado.loc['2018-01-01':'2019-01-01']
Year2019 = Resultado.loc['2019-01-01':'2020-01-01']
Year2020 = Resultado.loc['2020-01-01':'2021-01-01']
Year2021 = Resultado.loc['2021-01-01':'2022-01-01']

Years = [Year2009,Year2010,Year2011,Year2012,Year2013,Year2014,Year2015,'Year2016',Year2018,Year2019,Year2020,'Year2021']

# Year2010.countplot()
display(Year2021)
# display(Years[8])
# Out:
# FECHA DE MUESTREO
# 2021-02-04    31.53
# 2021-02-04    31.60
# 2021-04-08    36.03
# 2021-05-19    36.30
# 2021-07-06    30.85
# 2021-07-06    30.38
# 2021-09-23    36.16
# 2021-09-23    33.71
# 2021-09-23    36.13
# Name: RESULTADO, dtype: float64

# %%
def IndepthAnalysisHist(year):
    box40 = []
    box50 = []
    box60 = []
    box70 = []
    box80 = []
    box90 = []
    box100 = []
    for i in range(len(year)):
        if year[i]>30 and year[i]<40:
            box40.append(year[i])
    for i in range(len(year)):
        if year[i]>40 and year[i]<50:
            box50.append(year[i])
    for i in range(len(year)):
        if year[i]>50 and year[i]<60:
            box60.append(year[i])
    for i in range(len(year)):
        if year[i]>60 and year[i]<70:
            box70.append(year[i])
    for i in range(len(year)):
        if year[i]>70 and year[i]<80:
            box80.append(year[i])
    for i in range(len(year)):
        if year[i]>90 and year[i]<100:
            box90.append(year[i])
    for i in range(len(year)):
            box100.append(year[i])

    totBox = box40 + box50 + box60 + box70 + box80 + box90 + box100
    totLen = len(box40) + len(box50) + len(box60) + len(box70) + len(box80) + len(box90) + len(box100)
    Percentage = [len(box40)/totLen,len(box50)/totLen,len(box60)/totLen,len(box70)/totLen,len(box80)/totLen,len(box90)/totLen,len(box100)/totLen]
    df = pd.DataFrame(totBox)
    plt.hist(totBox, weights=np.ones(len(totBox))/len(totBox),bins=[30,40,50,60,70,80,90,100], color='gray', stacked=True)
    plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
    plt.ylabel('%TOT')
    plt.xlabel('mg/L Nitrate')

    return

# %%
print(IndepthAnalysisHist(Year2020))
# Out:
# None

# %%
def IndepthAnalysisBoxplot(year):
    box40 = []
    box50 = []
    box60 = []
    box70 = []
    box80 = []
    box90 = []
    box100 = []
    for i in range(len(year)):
        if year[i]>30 and year[i]<40:
            box40.append(year[i])
    for i in range(len(year)):
        if year[i]>40 and year[i]<50:
            box50.append(year[i])
    for i in range(len(year)):
        if year[i]>50 and year[i]<60:
            box60.append(year[i])
    for i in range(len(year)):
        if Year2010[i]>60 and year[i]<70:
            box70.append(year[i])
    for i in range(len(year)):
        if year[i]>70 and year[i]<80:
            box80.append(year[i])
    for i in range(len(year)):
        if year[i]>90 and year[i]<100:
            box90.append(year[i])
    for i in range(len(year)):
        if year[i]>100:
            box100.append(year[i])

    totBox = box40 + box50 + box60 + box70 + box80 + box90 + box100
    totLen = len(box40) + len(box50) + len(box60) + len(box70) + len(box80) + len(box90) + len(box100)
    Percentage = [len(box40)/totLen,len(box50)/totLen,len(box60)/totLen,len(box70)/totLen,len(box80)/totLen,len(box90)/totLen,len(box100)/totLen]
    data = pd.DataFrame(totBox)
    plt.boxplot(data[0])
    plt.ylabel('mg/l Nitrate')
    return

# %%
IndepthAnalysisBoxplot(Year2010);

# %%
def Data(year):
    box40 = []
    box50 = []
    box60 = []
    box70 = []
    box80 = []
    box90 = []
    box100 = []
    for i in range(len(year)):
        if year[i]>30 and year[i]<40:
            box40.append(year[i])
    for i in range(len(year)):
        if year[i]>40 and year[i]<50:
            box50.append(year[i])
    for i in range(len(year)):
        if year[i]>50 and year[i]<60:
            box60.append(year[i])
    for i in range(len(year)):
        if year[i]>60 and year[i]<70:
            box70.append(year[i])
    for i in range(len(year)):
        if year[i]>70 and year[i]<80:
            box80.append(year[i])
    for i in range(len(year)):
        if year[i]>90 and year[i]<100:
            box90.append(year[i])
    for i in range(len(year)):
        if year[i]>100:
            box100.append(year[i])

    totBox = box40 + box50 + box60 + box70 + box80 + box90 + box100
    totLen = len(box40) + len(box50) + len(box60) + len(box70) + len(box80) + len(box90) + len(box100)
    Percentage = [len(box40)/totLen,len(box50)/totLen,len(box60)/totLen,len(box70)/totLen,len(box80)/totLen,len(box90)/totLen,len(box100)/totLen]
    data = pd.DataFrame(totBox)

    return data.mean()

print(Data(Year2014))
# Out:
# 0    48.126667
# dtype: float64

# %%
YearsNames = ['2009','2010','2011','2012','2013','2014','2015','2018','2019','2020']

Years = [Year2009,Year2010,Year2011,Year2012,Year2013,Year2014,Year2015,Year2018,Year2019,Year2020]



Means = []
for i in range(10):
    Means.append(Data(Years[i])[0])

data = {'Years':YearsNames, 'Means':Means}
MeansData = pd.DataFrame(data)
print(MeansData)
fig = plt.figure(figsize=(12,7))

plt.plot(MeansData['Years'],MeansData['Means'])
plt.xticks(rotation=90)
plt.xlabel('Years')
plt.ylabel('Mg/l nitrate')
plt.axvspan(1, 6, facecolor='y', alpha=0.5, label = 'la Nina')
plt.axvspan(6, 9, facecolor='g', alpha=0.5, label = 'la Nino')

plt.legend()
plt.ylim(0,100)
plt.axhline(40, color = 'green')
plt.axhline(30, color = 'red')

plt.title('Yearly means_from30mg')
plt.savefig('Yearly means_Oreamuno_from30mg')
# Out:
#   Years      Means
# 0  2009  47.103077
# 1  2010  39.391250
# 2  2011  45.203333
# 3  2012  45.647273
# 4  2013  46.180000
# 5  2014  48.126667
# 6  2015  45.520500
# 7  2018  40.702593
# 8  2019  42.310000
# 9  2020  41.771250

# %%
YearsNames = ['2009','2010','2011','2012','2013','2014','2015','2018','2019','2020']

Years = [Year2009,Year2010,Year2011,Year2012,Year2013,Year2014,Year2015,Year2018,Year2019,Year2020]



Means = []
for i in range(10):
    Means.append(Data(Years[i])[0])

data = {'Years':YearsNames, 'Means':Means}
MeansData = pd.DataFrame(data)
print(MeansData)
fig = plt.figure(figsize=(12,7))

plt.plot(MeansData['Years'],MeansData['Means'])
plt.xticks(rotation=90)
plt.xlabel('Years')
plt.ylabel('Mg/l nitrate')
plt.axvspan(1, 6, facecolor='y', alpha=0.5, label = 'la Nina')
plt.axvspan(6, 9, facecolor='g', alpha=0.5, label = 'la Nino')

plt.legend()
plt.ylim(0,100)
plt.axhline(40, color = 'green')
plt.axhline(30, color = 'red')

plt.title('Yearly means')
plt.savefig('Yearly means_Oreamuno_Combined')
# Out:
#   Years      Means
# 0  2009  47.103077
# 1  2010  39.391250
# 2  2011  45.203333
# 3  2012  45.647273
# 4  2013  46.180000
# 5  2014  48.126667
# 6  2015  45.520500
# 7  2018  40.702593
# 8  2019  42.310000
# 9  2020  41.771250

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
RSore=read_csv('Potrero Cerrado, Oreamuno.csv', parse_dates=[1],skiprows=[0], skipinitialspace=True,delimiter=';',index_col=([0,1]))

# %%
Rstacked=RSore.stack()

# %%
Rstacked.index.names=['year', 'month', 'day']

# %%
cols=Rstacked.index.names=['year', 'month', 'day']
print(cols)
# Out:
# ['year', 'month', 'day']

# %%
import xlsxwriter

# %%
workbook = xlsxwriter.Workbook('Expenses01.xlsx')
worksheet = workbook.add_worksheet()

# %%
Rgd=read_csv('Oreamunogdunmerged.csv',skipinitialspace=True,delimiter=';',index_col=([0,1,2]))

# %%
Rgd.index=pd.to_datetime(Rgd.index.get_level_values(0).astype(str) + ' ' +
               Rgd.index.get_level_values(1).astype(str)+' ' +
               Rgd.index.get_level_values(2).astype(str) ,
               format='%Y %m %d')

# %%
plt.figure(figsize=((15,8)))
plt.plot(Rgd,label='rainfall in mm/d')
plt.title('Rainfall and Nitrate concentration in Oreamuno')
plt.plot(Resultado,'r.',label='Nitrate concentration over 30mg/l')
plt.legend()
plt.xlabel('date')
plt.ylabel('[mm/d] & [mg/l]')
plt.xlim(14400,17800)
# Out:
# (14400, 17800)
