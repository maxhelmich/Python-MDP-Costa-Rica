# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv
import datetime as dt
import matplotlib.dates as mdates
import matplotlib.cbook as cbook
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)

# %%
CR=read_csv('Cartago, costa rica 2009-01-01 to 2022-12-31.csv', parse_dates=[0],skiprows=[1], skipinitialspace=True, index_col=1)

# %%
display(CR.head(5))
# Out:
#                            name  tempmax  tempmin  temp  feelslikemax  \
# datetime
# 2009-01-02  Cartago, costa rica     26.8     19.1  22.3          27.6
# 2009-01-03  Cartago, costa rica     27.2     19.1  22.9          27.8
# 2009-01-04  Cartago, costa rica     28.2     20.1  23.5          28.6
# 2009-01-05  Cartago, costa rica     26.3     19.1  22.8          26.3
# 2009-01-06  Cartago, costa rica     27.9     18.1  22.7          29.0
#
#             feelslikemin  feelslike   dew  humidity  precip  ...  solarenergy  \
# datetime                                                     ...
# 2009-01-02          19.1       22.4  15.8      67.2   0.000  ...          NaN
# 2009-01-03          19.1       23.0  15.2      62.1   0.000  ...          NaN
# 2009-01-04          20.1       23.6  16.4      65.0   0.000  ...          NaN
# 2009-01-05          19.1       22.8  17.5      72.6   1.138  ...          NaN
# 2009-01-06          18.1       22.9  18.0      75.7   0.000  ...          NaN
#
# ...

# %%
print('Names of columns:')
print(CR.keys())
for key in CR.keys():
    print(key)
# Out:
# Names of columns:
# Index(['name', 'tempmax', 'tempmin', 'temp', 'feelslikemax', 'feelslikemin',
#        'feelslike', 'dew', 'humidity', 'precip', 'precipprob', 'precipcover',
#        'preciptype', 'snow', 'snowdepth', 'windgust', 'windspeed', 'winddir',
#        'sealevelpressure', 'cloudcover', 'visibility', 'solarradiation',
#        'solarenergy', 'uvindex', 'severerisk', 'sunrise', 'sunset',
#        'moonphase', 'conditions', 'description', 'icon', 'stations'],
#       dtype='object')
# name
# tempmax
# tempmin
# temp
# feelslikemax
# feelslikemin
# feelslike
# dew
# humidity
# precip
# precipprob
# precipcover
# preciptype
# snow
# snowdepth
# windgust
# windspeed
# winddir
# sealevelpressure
# cloudcover
# visibility
# solarradiation
# solarenergy
# uvindex
# severerisk
# sunrise
# sunset
# moonphase
# conditions
# description
# icon
# stations

# %%
print(CR.loc[:,'precip'])
# Out:
# datetime
# 2009-01-02    0.000
# 2009-01-03    0.000
# 2009-01-04    0.000
# 2009-01-05    1.138
# 2009-01-06    0.000
#               ...
# 2022-12-27      NaN
# 2022-12-28      NaN
# 2022-12-29      NaN
# 2022-12-30      NaN
# 2022-12-31      NaN
# Name: precip, Length: 5112, dtype: float64

# %%
plt.figure(figsize=[15,9])
plt.plot(CR['datetime'],CR['precip'])
plt.ylabel('Precipitation [mm/d]')
plt.xlabel('year')
# plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
# locator.intervald[YEARLY] = [1]
# tFmt = mdates.DateFormatter('%Y-%b') # define the formatting
# plt.gca().xaxis.set_major_formatter(dtFmt) 
# # show every 12th tick on x axes
# plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# plt.xticks(rotation=90, fontweight='light',  fontsize='x-small',)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'datetime'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
plt.figure(figsize=[15,8])


N = CR['datetime']
y = CR['precip']
# now = dt.datetime.now()
# then = now + dt.timedelta(days=100)
# days = mdates.drange(now,then,dt.timedelta(days=1))
# plt.figure(figsize=[15,9])
# plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
plt.plot(N,y)
# plt.gcf().autofmt_xdate()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'datetime'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
CR['precip'].iloc['2009-01-02']

# %%
CR.loc['2009-01-05','precip']

# %%
print(CR['precip'].max())
print(CR['precip'].argmax())
print(CR([0]))

# %%
Resultados
